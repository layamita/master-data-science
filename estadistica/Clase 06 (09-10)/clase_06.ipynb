# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import stats

# %% [markdown]
# A worker can arrive to the workplace at any moment between 6 and 7 in the morning with the same likelihood.
#
# •Compute and plot the probability density function of the variable that measures the arrival time. compute and plot the distribution function. Compute the probability of arriving before quarter past six and after half past six. What is the expected arrival time?

# %%
tmp = stats.uniform(6,1);

# %%
tmp.cdf(7)-tmp.cdf(6)
# Out:
# 1.0

# %%
x = np.linspace(5,8,100)

# %%
plt.plot(x,tmp.pdf(x));

# %%
x = np.linspace(5,8,100)
plt.plot(x,tmp.pdf(x));

xp1=np.linspace(5,6.25,100)
plt.fill_between(xp1,tmp.pdf(xp1), color="red")

xp2=np.linspace(6.5,8,100)
plt.fill_between(xp2,tmp.pdf(xp2), color="red");

# %%
(tmp.cdf(6.25)-tmp.cdf(6))+(tmp.cdf(7)-tmp.cdf(6.5))
# Out:
# 0.75

# %% [markdown]
# El tiempo de reparación de unas máquinas de escribir sigue una distribución exponencial, con media de 22 minutos.
#
# •Hallar la probabilidad de que el tiempo de reparación sea menor que 10 minutos.
# •El costo de la reparación es de 20 euros por cada media hora o fracción. ¿Cuál es la probabilidad de que una reparación cueste 40 euros?
# •Para efectuar una programación, ¿cuánto tiempo se debe asignar a cada reparación para que la probabilidad de que cualquier tiempo de reparación mayor que el tiempo asignado sea solo de 1/10

# %%
tmp = stats.expon(scale=22);

# %%
tmp.cdf(10)
# Out:
# 0.3652635810597182

# %%
x = np.linspace(0,100,1000)
plt.plot(x,tmp.pdf(x));

xp1=np.linspace(0,10,100)
plt.fill_between(xp1,tmp.pdf(xp1), color="red");

# %%
tmp.cdf(60)-tmp.cdf(30)
# Out:
# 0.19033175668324043

# %%
x = np.linspace(0,100,1000)
plt.plot(x,tmp.pdf(x));

xp1=np.linspace(30,60,100)
plt.fill_between(xp1,tmp.pdf(xp1), color="red");

# %% [markdown]
# ¿cuánto tiempo se debe asignar a cada reparación para que la probabilidad de que cualquier tiempo de reparación mayor que el tiempo asignado sea solo de 1/10

# %%
tmp.ppf(.9)
# Out:
# 50.65687204586901

# %% [markdown]
# Se ha comprobado que el tiempo de vida de cierto tipo de marcapasos sigue una distribución exponencial con media de 16 años.
#
# •¿Cuál es la probabilidad de que a una persona a la que se le ha implantado este marcapasos se le tenga que implantar otro antes de 20 años?
# •Si el marcapasos lleva funcionando correctamente 5 años en un paciente, ¿cuál es la probabilidad de que haya que cambiarlo antes de 25 años?

# %%
tmp = stats.expon(scale=16);

# %%
tmp.cdf(20)
# Out:
# 0.7134952031398099

# %%
x = np.linspace(0,50,1000)
plt.plot(x,tmp.pdf(x))
xp1=np.linspace(0,20,100)
plt.fill_between(xp1,tmp.pdf(xp1), color="red");

# %%
(tmp.cdf(25)-tmp.cdf(5))/(1-tmp.cdf(5))
# Out:
# 0.7134952031398099

# %%
tmp.cdf(25)-tmp.cdf(5)
# Out:
# 0.5220042417955439

# %% [markdown]
# The curing time of a knee injury in soccer players follows a normal distribution model with mean 50 days and standard deviation 10 days.
# *If there is a finalmatch in 65 days, what is the probability that a player that has just injured his knee will miss the final?
# *If the semifinal match is in 40 days, and 4 players has just injured the knee, what is the probability that some of them can play the semifinal?

# %%
tmp = stats.norm(50,10);

# %%
1-tmp.cdf(65)
# Out:
# 0.06680720126885809

# %%
1-tmp.cdf(40)
# Out:
# 0.8413447460685429

# %%
#binomial n=4 p=.84
#p(t>=1) = 1-p(t=0)
tmp = stats.binom(4,.84)
1-tmp.binom(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-6a9686bcc7db> in <module>
#       2 #p(t>=1) = 1-p(t=0)
#       3 tmp = stats.binom(4,.84)
# ----> 4 1-tmp.binom(0)
#
# AttributeError: 'rv_frozen' object has no attribute 'binom'

# %% [markdown]
# Las ventas diarias de una empresa siguen una distribución uniforme entre 300 y 600 euros. Suponiendo independientes las ventas de los distintos días del año, calcular la probabilidad de que el volumen de ventas anual supere los 138.000 euros, si la empresa trabaja 300 días al año.

# %%
tmp = stats.uniform(loc=300,scale=600-300)

# %%
x = np.linspace(250,650,500)
plt.plot(x,tmp.pdf(x));

# %%
suma_unif = stats.norm(300*tmp.mean(),np.sqrt(300)*tmp.std())

# %%
1-suma_unif.cdf(138000)
# Out:
# 0.02275013194817921
