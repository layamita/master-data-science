# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import seaborn as sns

# %%
from scipy import stats

# %%
import pandas as pd
rio = pd.read_csv('rioTimes.csv')
KatieTimes=rio[rio["name"]=="Katie LEDECKY"]["time"].values

# %%
KatieTimes
# Out:
# array([28.39, 30.42, 30.2 , 30.94, 30.87, 31.28, 30.92, 31.32, 31.21,
#        31.56, 31.28, 31.63, 31.36, 31.43, 31.32, 30.5 ])

# %%
plt.plot(KatieTimes);
