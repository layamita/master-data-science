# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
#Equivalente a esto

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.datasets import california_housing
data = california_housing.fetch_california_housing()
income = data.data[:,0]

# %%
len(income)
# Out:
# 20640

# %%
type(income)
# Out:
# numpy.ndarray

# %%
np.mean(income)
# Out:
# 3.8706710029069766

# %%
np.min(income)
# Out:
# 0.4999

# %%
np.max(income)
# Out:
# 15.0001

# %%
np.max(income)-np.min(income)
# Out:
# 14.5002

# %%
plt.figure(figsize=(15,10))
plt.hist(income,bins=50);

# %%
plt.figure(figsize=(15,10))
plt.hist(income,bins=50);
plt.axvline(x=np.mean(income),color='red');

# %%
plt.figure(figsize=(15,10))
plt.hist(income,bins=50);
plt.axvline(x=np.mean(income),color='red')
plt.axvline(x=np.max(income),color='green')
plt.axvline(x=np.min(income),color='blue');

# %%
np.mean(np.abs(income-np.mean(income)))
# Out:
# 1.4016136452417973

# %%
income
# Out:
# array([8.3252, 8.3014, 7.2574, ..., 1.7   , 1.8672, 2.3886])

# %%
(income-np.mean(income))**2
# Out:
# array([19.84282859, 19.63135945, 11.4699333 , ...,  4.7118126 ,
#         4.01389606,  2.19653446])

# %%
np.mean((income-np.mean(income))**2)
# Out:
# 3.609147689697444

# %%
np.var(income)
# Out:
# 3.609147689697444

# %%
np.std(income)
# Out:
# 1.8997756945748738

# %%
sorted(income)[10319]
# Out:
# 3.5347

# %%
np.median(income)
# Out:
# 3.5347999999999997

# %%
    np.percentile(income,75)
# Out:
# 4.74325

# %%
    np.percentile(income,75)-np.percentile(income,25)
# Out:
# 2.17985
