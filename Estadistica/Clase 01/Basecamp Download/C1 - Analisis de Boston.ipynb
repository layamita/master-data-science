# %%
# %pylab inline
import pandas as pd
df = pd.read_csv('Boston.csv')

def extract_samples(gender,year):
    return df[(df["YEAR"]==year)&(df["GENDER"]==gender)]["TIMES"].values

def extract_top_samples(gender,year):
    return sorted(df[(df["TIMES"]>7200)&(df["YEAR"]==year)&(df["GENDER"]==gender)]["TIMES"].values)[:100]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
times = extract_samples("F",1981)

# %%
plt.hist(times,bins=50)
plt.axvline(x=np.mean(times),color="red");

# %%
np.std(times)
# Out:
# 1015.4135285624232

# %%
np.mean(extract_samples("M",2012))
# Out:
# 13714.831040480709

# %%
years = df["YEAR"].unique()

# %%
medias = [np.mean(extract_samples("M",year)) for year in years]

# %%
plt.plot(years,medias)

# %%
stds = [np.std(extract_samples("M",year)) for year in years]
plt.plot(stds)

# %%
medias_top = [np.mean(extract_top_samples("M",year)) for year in years]

# %%
plt.plot(years,medias_top)

# %%
std_top = [np.std(extract_top_samples("M",year)) for year in years]

# %%
plt.plot(years,std_top)
