# %% [markdown]
# # Loading CSV

# %%
import pandas as pd
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
df = pd.read_csv('../../sources/914310910_T_T100_SEGMENT_ALL_CARRIER_2015_All.csv')
df.head()
# Out:
#    DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED  PAYLOAD  SEATS  PASSENGERS  \
# 0                   0.0                   1.0    528.0   11.0         2.0
# 1                   0.0                   2.0   3621.0   22.0         2.0
# 2                   0.0                   1.0   2169.0   11.0         2.0
# 3                   0.0                   1.0   1342.0   11.0         1.0
# 4                   0.0                   1.0    275.0   11.0         1.0
#
#    FREIGHT  MAIL  DISTANCE  RAMP_TO_RAMP  AIR_TIME  ... AIRCRAFT_GROUP  \
# 0      0.0   0.0    3899.0           0.0       0.0  ...              6
# 1      0.0   0.0    2589.0           0.0       0.0  ...              6
# 2      0.0   0.0    1210.0           0.0       0.0  ...              6
# 3      0.0   0.0    2316.0           0.0       0.0  ...              6
# 4      0.0   0.0    1023.0           0.0       0.0  ...              6
#
#    AIRCRAFT_TYPE AIRCRAFT_CONFIG  YEAR QUARTER MONTH DISTANCE_GROUP  CLASS  \
# ...

# %%
df.columns
# Out:
# Index(['DEPARTURES_SCHEDULED', 'DEPARTURES_PERFORMED', 'PAYLOAD', 'SEATS',
#        'PASSENGERS', 'FREIGHT', 'MAIL', 'DISTANCE', 'RAMP_TO_RAMP', 'AIR_TIME',
#        'UNIQUE_CARRIER', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
#        'UNIQUE_CARRIER_ENTITY', 'REGION', 'CARRIER', 'CARRIER_NAME',
#        'CARRIER_GROUP', 'CARRIER_GROUP_NEW', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS',
#        'ORIGIN_STATE_NM', 'ORIGIN_COUNTRY', 'ORIGIN_COUNTRY_NAME',
#        'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID',
#        'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_STATE_ABR',
#        'DEST_STATE_FIPS', 'DEST_STATE_NM', 'DEST_COUNTRY', 'DEST_COUNTRY_NAME',
#        'DEST_WAC', 'AIRCRAFT_GROUP', 'AIRCRAFT_TYPE', 'AIRCRAFT_CONFIG',
#        'YEAR', 'QUARTER', 'MONTH', 'DISTANCE_GROUP', 'CLASS', 'DATA_SOURCE',
#        'Unnamed: 50'],
#       dtype='object')

# %%
df[df['PASSENGERS'] > 1000]
# Out:
#         DEPARTURES_SCHEDULED  DEPARTURES_PERFORMED     PAYLOAD    SEATS  \
# 14                       0.0                   9.0    562962.0   2548.0
# 15                       0.0                  18.0   1237995.0   5159.0
# 16                       0.0                   9.0    565173.0   2595.0
# 17                       0.0                  18.0   1237436.0   5109.0
# 19                       0.0                   9.0    910800.0   2835.0
# 21                       0.0                   9.0    910800.0   2835.0
# 22                       0.0                  23.0   2345933.0   6793.0
# 23                       0.0                  29.0   2557427.0   8525.0
# 24                       0.0                  12.0   1049765.0   3569.0
# 25                       0.0                  23.0   2401058.0   6793.0
# 26                       0.0                  21.0   2199395.0   6180.0
# 27                       0.0                  29.0   3020211.0   8530.0
# ...

# %%
df[df['PASSENGERS'] > 1000][['ORIGIN_CITY_NAME']]
# Out:
#            ORIGIN_CITY_NAME
# 14         Guangzhou, China
# 15          Shanghai, China
# 16               Saipan, TT
# 17               Saipan, TT
# 19                Tampa, FL
# 21      Zurich, Switzerland
# 22      Dusseldorf, Germany
# 23      Dusseldorf, Germany
# 24      Dusseldorf, Germany
# 25             New York, NY
# 26             New York, NY
# 27                Miami, FL
# 28                Miami, FL
# 29              Chicago, IL
# 30           Fort Myers, FL
# 31          Berlin, Germany
# 32          Berlin, Germany
# 33          Berlin, Germany
# 37              Atlanta, GA
# 40               Boston, MA
# 42            Paris, France
# 43            Paris, France
# 47            Paris, France
# 48            Paris, France
# 49            Paris, France
# 50            Paris, France
# 51            Paris, France
# 53            Paris, France
# 54            Paris, France
# 55            Paris, France
# ...                     ...
# 146907           Tinian, TT
# ...

# %%
df.columns
# Out:
# Index(['DEPARTURES_SCHEDULED', 'DEPARTURES_PERFORMED', 'PAYLOAD', 'SEATS',
#        'PASSENGERS', 'FREIGHT', 'MAIL', 'DISTANCE', 'RAMP_TO_RAMP', 'AIR_TIME',
#        'UNIQUE_CARRIER', 'AIRLINE_ID', 'UNIQUE_CARRIER_NAME',
#        'UNIQUE_CARRIER_ENTITY', 'REGION', 'CARRIER', 'CARRIER_NAME',
#        'CARRIER_GROUP', 'CARRIER_GROUP_NEW', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'ORIGIN',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_FIPS',
#        'ORIGIN_STATE_NM', 'ORIGIN_COUNTRY', 'ORIGIN_COUNTRY_NAME',
#        'ORIGIN_WAC', 'DEST_AIRPORT_ID', 'DEST_AIRPORT_SEQ_ID',
#        'DEST_CITY_MARKET_ID', 'DEST', 'DEST_CITY_NAME', 'DEST_STATE_ABR',
#        'DEST_STATE_FIPS', 'DEST_STATE_NM', 'DEST_COUNTRY', 'DEST_COUNTRY_NAME',
#        'DEST_WAC', 'AIRCRAFT_GROUP', 'AIRCRAFT_TYPE', 'AIRCRAFT_CONFIG',
#        'YEAR', 'QUARTER', 'MONTH', 'DISTANCE_GROUP', 'CLASS', 'DATA_SOURCE',
#        'Unnamed: 50'],
#       dtype='object')

# %%
df[df['DEST_CITY_NAME'] == 'Berlin, Germany'][['PASSENGERS']].sum()
# Out:
# PASSENGERS    66054.0
# dtype: float64

# %% [markdown]
# # Saving to Excel

# %%
result = df[df['DEST_CITY_NAME'] == 'Berlin, Germany'][['PASSENGERS']].sum()
result.to_excel('result.xls')

# %% [markdown]
# # Saving to CSV

# %%
result = df[df['DEST_CITY_NAME'] == 'Berlin, Germany'][['PASSENGERS']].sum()
result.to_csv('result.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %% [markdown]
# # To Sql Database

# %%
import sqlite3
con = sqlite3.connect('newdb.db')

result = df[df['DEST_CITY_NAME'] == 'Berlin, Germany'][['PASSENGERS']]

result.to_sql('my_new_table', con=con, if_exists="replace")

# %% [markdown]
# # To dictionary and to json

# %%
result = df[df['DEST_CITY_NAME'] == 'Berlin, Germany'][:6]
result.head().to_dict()
# Out:
# {'DEPARTURES_SCHEDULED': {26: 0.0, 28: 0.0, 29: 0.0, 8373: 0.0, 8375: 0.0},
#  'DEPARTURES_PERFORMED': {26: 21.0,
#   28: 22.0,
#   29: 14.0,
#   8373: 20.0,
#   8375: 20.0},
#  'PAYLOAD': {26: 2199395.0,
#   28: 2294431.0,
#   29: 1466137.0,
#   8373: 2090143.0,
#   8375: 2079559.0},
#  'SEATS': {26: 6180.0, 28: 6480.0, 29: 4130.0, 8373: 5890.0, 8375: 5895.0},
#  'PASSENGERS': {26: 4683.0,
#   28: 5596.0,
#   29: 2468.0,
#   8373: 4613.0,
#   8375: 4947.0},
#  'FREIGHT': {26: 573408.0,
#   28: 507333.0,
#   29: 249731.0,
#   8373: 394123.0,
#   8375: 490948.0},
#  'MAIL': {26: 0.0, 28: 0.0, 29: 0.0, 8373: 0.0, 8375: 0.0},
#  'DISTANCE': {26: 3968.0, 28: 4974.0, 29: 4413.0, 8373: 3968.0, 8375: 4974.0},
#  'RAMP_TO_RAMP': {26: 0.0, 28: 0.0, 29: 0.0, 8373: 0.0, 8375: 0.0},
#  'AIR_TIME': {26: 0.0, 28: 0.0, 29: 0.0, 8373: 0.0, 8375: 0.0},
#  'UNIQUE_CARRIER': {26: 'AB', 28: 'AB', 29: 'AB', 8373: 'AB', 8375: 'AB'},
#  'AIRLINE_ID': {26: 21361.0,
#   28: 21361.0,
#   29: 21361.0,
# ...

# %%
result = df[df['DEST_CITY_NAME'] == 'Berlin, Germany'][:6]
result.head().to_json()
# Out:
# '{"DEPARTURES_SCHEDULED":{"26":0.0,"28":0.0,"29":0.0,"8373":0.0,"8375":0.0},"DEPARTURES_PERFORMED":{"26":21.0,"28":22.0,"29":14.0,"8373":20.0,"8375":20.0},"PAYLOAD":{"26":2199395.0,"28":2294431.0,"29":1466137.0,"8373":2090143.0,"8375":2079559.0},"SEATS":{"26":6180.0,"28":6480.0,"29":4130.0,"8373":5890.0,"8375":5895.0},"PASSENGERS":{"26":4683.0,"28":5596.0,"29":2468.0,"8373":4613.0,"8375":4947.0},"FREIGHT":{"26":573408.0,"28":507333.0,"29":249731.0,"8373":394123.0,"8375":490948.0},"MAIL":{"26":0.0,"28":0.0,"29":0.0,"8373":0.0,"8375":0.0},"DISTANCE":{"26":3968.0,"28":4974.0,"29":4413.0,"8373":3968.0,"8375":4974.0},"RAMP_TO_RAMP":{"26":0.0,"28":0.0,"29":0.0,"8373":0.0,"8375":0.0},"AIR_TIME":{"26":0.0,"28":0.0,"29":0.0,"8373":0.0,"8375":0.0},"UNIQUE_CARRIER":{"26":"AB","28":"AB","29":"AB","8373":"AB","8375":"AB"},"AIRLINE_ID":{"26":21361.0,"28":21361.0,"29":21361.0,"8373":21361.0,"8375":21361.0},"UNIQUE_CARRIER_NAME":{"26":"Air Berlin PLC and CO","28":"Air Berlin PLC and CO","29":"Air Be
# ...

# %% [markdown]
# # Reading Excel

# %%
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html
pd.read_excel('result.xls')
# Out:
#    Unnamed: 0      0
# 0  PASSENGERS  66054

# %% [markdown]
# #### Exercise
#
# Consolidate the excel into one DataFrame: you will need to create a 'YEAR' column. Think how you can iterate through all the DataFrames. Think also where you can take the value of 'YEAR' from.

# %%
#https://datos.madrid.es/portal/site/egob/

# %% [markdown]
# # Reading mysql database

# %%
pd.read_sql_query('select SUM(PASSENGERS) from my_new_table',con)
# Out:
#    SUM(PASSENGERS)
# 0          66054.0
